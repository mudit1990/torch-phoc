# %% [markdown]
# ### Set up block

# %%
import argparse
import logging

import numpy as np
import torch.autograd
import torch.cuda
import torch.nn as nn
import torch.optim
from torch.utils.data import DataLoader
import tqdm

import copy
#from datasets.maps_alt import MAPSDataset
#from maps_alt import MAPSDataset
from datasets.maps_alt import MAPSDataset

#from cnn_ws.transformations.homography_augmentation import HomographyAugmentation
from cnn_ws.losses.cosine_loss import CosineLoss

from cnn_ws.models.myphocnet import PHOCNet
from cnn_ws.evaluation.retrieval import map_from_feature_matrix, map_from_query_test_feature_matrices
from torch.utils.data.dataloader import _DataLoaderIter as DataLoaderIter
from torch.utils.data.sampler import WeightedRandomSampler

from cnn_ws.utils.save_load import my_torch_save, my_torch_load

import matplotlib.pyplot as plt
from cnn_ws.string_embeddings.phoc import build_phoc_descriptor

from scipy.spatial.distance import cdist, pdist, squareform
# from dist_func import damerau_levenshtein_distance as dld

def report_matches(outputs, embedding, matching, word_strings, original_words, k, length, is_lower):
    # length sorting stuff
    qualified_ids = [x for x in range(len(word_strings)) if len(word_strings[x]) > length]
    qualified_ids_original = [x for x in range(len(original_words)) if len(original_words[x]) > length]
    outputs = np.array(outputs)
    embedding = np.array(embedding)
    word_strings = np.array(word_strings)
    original_words = np.array(original_words)
    outputs = list(outputs[qualified_ids_original])
    embedding = list(embedding[qualified_ids])
    word_strings = list(word_strings[qualified_ids])
    original_words = list(original_words[qualified_ids_original])
    # the real computation
    dist_mat = cdist(XA=outputs, XB=embedding, metric=matching)
    retrieval_indices = np.argsort(dist_mat, axis=1)
    q = retrieval_indices[:,:k]
    count = 0
    matched_words = []
    # get all matched words
    #print len(outputs), len(embedding)
    for i in range(len(q)):
        matched = []
        #print q[i]
        for j in q[i]:
            matched.append(word_strings[j])
        matched_words.append(matched)
    
    #print len(word_strings), len(matched_words)
    close_counts = 0
    flag_match = np.zeros(len(original_words))
    for i in range(len(original_words)):
        #print original_words[i], matched_words[i]
        if is_lower:
            #print original_words[i], matched_words[i]
            if original_words[i] in matched_words[i]:
                #print "yes"
                count = count+1
                flag_match[i] = 1
                #print "matched: "+str(bool(flag_match[i]))
           # else:
                #print "no"
#                 pass
#                 for j in matched_words[i]:
#                     #print original_words[i], j, dld(original_words[i], j)
#                     if dld(original_words[i], j) == 1:
#                         close_counts = close_counts+1
#                 pass
        else:
            if original_words[i].lower() in [str(x.lower()) for x in matched_words[i]]:
                count = count+1
                flag_match[i] = 1
                
    #print count
    return count, close_counts, matched_words, outputs, embedding, word_strings, qualified_ids_original, flag_match

def learning_rate_step_parser(lrs_string):
    return [(int(elem.split(':')[0]), float(elem.split(':')[1])) for elem in lrs_string.split(',')]

# %% [markdown]
# ### Load model and data block

# %%
# parameters ######################################################################################
embedding_type = 'phoc'
bigram_levels = None
bigrams = None
phoc_unigram_levels = (1,2,4,8)
fixed_image_size = None
min_image_width_height = 26
is_lower = 1

# get the model ####################################################################################
if is_lower:
    n_out = 540
else:
    n_out = 945
cnn = PHOCNet(n_out=n_out,
    input_channels=3,
    gpp_type='gpp',
    pooling_levels=([1], [5]))

cnn.init_weights()

if is_lower == 1:
    model_ = torch.load('PHOCNet_final.pt')
else:
    model_ = torch.load('PHOCNet_all_case.pt')

cnn = model_.module

if not torch.cuda.is_available():
    logger.warning('Could not find CUDA environment, using CPU mode')
    gpu_id = None
else:
    gpu_id = [0]

if gpu_id is not None:
        if len(gpu_id) > 1:
            cnn = nn.DataParallel(cnn, device_ids=gpu_id)
            cnn.cuda()
        else:
            cnn.cuda(gpu_id[0])

# find the file names
f = open('../splits/val_files.txt', 'rb')
A = f.readlines()
f.close()
A = [x.rstrip('\n') for x in A]

# load test images and words
images = np.load('../../../ProcessedData/original_images_nopad_'+A[1]+'.tiff.npy')
words = np.load('../../../ProcessedData/original_words_nopad_'+A[1]+'.tiff.npy')

# filter false poitives
useful_ids = []
for i in range(len(words)):
    if words[i]  == 'no label attached':
        pass
    else:
        useful_ids.append(i)

images = images[useful_ids]
words = words[useful_ids]

original_words = np.copy(words)

if is_lower == 1:
    new_words = []
    for i in words:
        new_words.append(i.lower())
    words = np.array(new_words)
    original_words = np.copy(words)
else:    
    words = list(words)
    new_words = []
    for i in words:
        new_words.append(i.upper())
        new_words.append(i.lower())
        new_words.append(i.capitalize())
    words = np.array(new_words)

# convert dimensions
images = np.transpose(images, (0,3,1,2))
images.shape

# check if this works
outputs = []
for i in range(len(images)):
    word_img = images[i]
    word_img = 1 - word_img.astype(np.float32) / 255.0
    word_img = word_img.reshape((1,) + word_img.shape)
    word_img = torch.from_numpy(word_img).float()
    word_img = word_img.cuda(gpu_id[0])
    word_img = torch.autograd.Variable(word_img)
    output = torch.sigmoid(cnn(word_img))
    output = output.data.cpu().numpy().flatten()
    outputs.append(output)

# compute the PHOC representation of the word itself
word_strings = words
if is_lower == 0:
    unigrams = [chr(i) for i in range(ord('&'), ord('&')+1) + range(ord('A'), ord('Z')+1) + \
                    range(ord('a'), ord('z') + 1) + range(ord('0'), ord('9') + 1)]
else:
    unigrams = [chr(i) for i in range(ord('a'), ord('z') + 1) + range(ord('0'), ord('9') + 1)]


if is_lower == 1:
    for i in range(len(word_strings)):
        word_strings[i] = str(word_strings[i].lower())
else:
    pass

embedding = build_phoc_descriptor(words=word_strings,
                                  phoc_unigrams=unigrams,
                                  bigram_levels=bigram_levels,
                                  phoc_bigrams=bigrams,
                                  unigram_levels=phoc_unigram_levels)

print embedding.shape
# Out:
# 100%|██████████| 2069/2069 [00:00<00:00, 6272.62it/s]
# (2069, 540)

# %% [markdown]
# ### Output visualization block

# %%
count, close_count, matched_words, new_outputs, new_embedding, new_word_strings, \
        qualified_ids, flag_match = report_matches(outputs, embedding, 'cosine', word_strings, \
                                       original_words, k=2, length=3, is_lower=is_lower)

print "the accuracy is: "+str(count/float(len(qualified_ids)))
print "the close_count accuracy is: "+str(close_count/float(len(qualified_ids)))

_len = min(500, len(matched_words))
new_images = images[qualified_ids]
new_strings = word_strings[qualified_ids]
for i in range(_len):
    print "************************************************************************"
    print "************************************************************************"
    print "Original image:"
    q = np.transpose(new_images[i],(1,2,0))
    #plt.imshow(q)
    #plt.show()
    print "IoU matched word is: "+str(new_strings[i])
    print "the matched words are (inorder): "+str(matched_words[i])
    print "did it match?: "+str(bool(flag_match[i]))
    print "------------------------------------------------------------------------"
    print "------------------------------------------------------------------------"

pass
# Out:
# the accuracy is: 0.715231788079
# the close_count accuracy is: 0.0
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: carmel
# the matched words are (inorder): ['carmel', 'carmel']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: georgetown
# the matched words are (inorder): ['georgetown', 'greentown']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: city
# the matched words are (inorder): ['city', 'city']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: union
# the matched words are (inorder): ['union', 'union']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: delphi
# the matched words are (inorder): ['dalton', 'delphi']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: center
# the matched words are (inorder): ['center', 'center']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: yankeetown
# the matched words are (inorder): ['walkerton', 'walton']
# did it match?: False
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: crothersville
# the matched words are (inorder): ['coatesville', 'crothersville']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: cross
# the matched words are (inorder): ['cross', 'crown']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: cromwell
# the matched words are (inorder): ['corner', 'crosse']
# did it match?: False
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: hatchery
# the matched words are (inorder): ['hatchery', 'hatchery']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: walton
# the matched words are (inorder): ['walton', 'dalton']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: stilesville
# the matched words are (inorder): ['stilesville', 'shelbyville']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: michigan
# the matched words are (inorder): ['michigan', 'mechanics']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: attica
# the matched words are (inorder): ['attica', 'avoca']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: elrod
# the matched words are (inorder): ['elrod', 'elwood']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: hayden
# the matched words are (inorder): ['hayden', 'warren']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: bluffton
# the matched words are (inorder): ['fulton', 'benton']
# did it match?: False
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: hamlet
# the matched words are (inorder): ['anne', 'castle']
# did it match?: False
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: north
# the matched words are (inorder): ['north', 'north']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: springville
# the matched words are (inorder): ['springville', 'russiaville']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: ogden
# the matched words are (inorder): ['borden', 'omer']
# did it match?: False
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: james
# the matched words are (inorder): ['states', 'james']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: covington
# the matched words are (inorder): ['clinton', 'covington']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: muscatatuck
# the matched words are (inorder): ['metamora', 'eaton']
# did it match?: False
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: hymera
# the matched words are (inorder): ['warren', 'hayden']
# did it match?: False
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: tennyson
# the matched words are (inorder): ['tennyson', 'trenton']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: wakarusa
# the matched words are (inorder): ['walton', 'wawaka']
# did it match?: False
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: solsberry
# the matched words are (inorder): ['solsberry', 'sidney']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: park
# the matched words are (inorder): ['park', 'park']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: mcnally
# the matched words are (inorder): ['mcnally', 'mcnally']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: improved
# the matched words are (inorder): ['grove', 'grove']
# did it match?: False
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: town
# the matched words are (inorder): ['roann', 'town']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: clay
# the matched words are (inorder): ['city', 'city']
# did it match?: False
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: swayzee
# the matched words are (inorder): ['state', 'state']
# did it match?: False
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: state
# the matched words are (inorder): ['state', 'state']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: kennard
# the matched words are (inorder): ['kennard', 'ireland']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: chesterton
# the matched words are (inorder): ['chesterton', 'collection']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: fork
# the matched words are (inorder): ['fork', 'fork']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: lebanon
# the matched words are (inorder): ['lebanon', 'lebanon']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: dillsboro
# the matched words are (inorder): ['hillsboro', 'dillsboro']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: fortville
# the matched words are (inorder): ['brookville', 'perrysville']
# did it match?: False
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: green
# the matched words are (inorder): ['creek', 'green']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: momence
# the matched words are (inorder): ['momence', 'monroe']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: porter
# the matched words are (inorder): ['porter', 'corner']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: berne
# the matched words are (inorder): ['berne', 'anne']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: bainbridge
# the matched words are (inorder): ['bainbridge', 'dixie']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: henryville
# the matched words are (inorder): ['greenville', 'greenville']
# did it match?: False
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: martinsville
# the matched words are (inorder): ['martinsville', 'martinsville']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: dupont
# the matched words are (inorder): ['dupont', 'poor']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: state
# the matched words are (inorder): ['state', 'state']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: park
# the matched words are (inorder): ['paris', 'paris']
# did it match?: False
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: springs
# the matched words are (inorder): ['springs', 'springs']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: geneva
# the matched words are (inorder): ['geneva', 'center']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: bryant
# the matched words are (inorder): ['bryant', 'broad']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: paved
# the matched words are (inorder): ['paved', 'paved']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: vernon
# the matched words are (inorder): ['vernon', 'vernon']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: dale
# the matched words are (inorder): ['dale', 'made']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: oaklandon
# the matched words are (inorder): ['collection', 'atlantic']
# did it match?: False
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: doverhill
# the matched words are (inorder): ['collection', 'connecting']
# did it match?: False
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: butlerville
# the matched words are (inorder): ['butlerville', 'batesville']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: patoka
# the matched words are (inorder): ['patoka', 'paoli']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: park
# the matched words are (inorder): ['park', 'park']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: roanoke
# the matched words are (inorder): ['crosse', 'roads']
# did it match?: False
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: scottsburg
# the matched words are (inorder): ['shelburn', 'stone']
# did it match?: False
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: pierre
# the matched words are (inorder): ['pierre', 'palestine']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: cartography
# the matched words are (inorder): ['cartography', 'hatchery']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: atlas
# the matched words are (inorder): ['claypool', 'royal']
# did it match?: False
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: salem
# the matched words are (inorder): ['spiceland', 'green']
# did it match?: False
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: hobbs
# the matched words are (inorder): ['hobbs', 'shoals']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: lebanon
# the matched words are (inorder): ['lebanon', 'lebanon']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: lagro
# the matched words are (inorder): ['park', 'park']
# did it match?: False
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: newberry
# the matched words are (inorder): ['romney', 'rumsey']
# did it match?: False
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: griffin
# the matched words are (inorder): ['rosston', 'morton']
# did it match?: False
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: middletown
# the matched words are (inorder): ['milton', 'middletown']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: dunkirk
# the matched words are (inorder): ['dublin', 'dunkirk']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: hartsville
# the matched words are (inorder): ['hartsville', 'batesville']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: kankakee
# the matched words are (inorder): ['lake', 'lake']
# did it match?: False
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: newville
# the matched words are (inorder): ['newville', 'pennville']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: hoopeston
# the matched words are (inorder): ['hoopeston', 'houston']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: mulberry
# the matched words are (inorder): ['valley', 'valley']
# did it match?: False
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: jefferson
# the matched words are (inorder): ['jefferson', 'henderson']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: newton
# the matched words are (inorder): ['newton', 'benton']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: harrodsburg
# the matched words are (inorder): ['sandborn', 'hammond']
# did it match?: False
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: warren
# the matched words are (inorder): ['warren', 'marker']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: poor
# the matched words are (inorder): ['poor', 'poor']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: proposed
# the matched words are (inorder): ['proposed', 'proposed']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: brazil
# the matched words are (inorder): ['brazil', 'bass']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: waveland
# the matched words are (inorder): ['waveland', 'wingate']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: plainfield
# the matched words are (inorder): ['plainfield', 'princeton']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: city
# the matched words are (inorder): ['city', 'city']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: rockville
# the matched words are (inorder): ['rossville', 'rossville']
# did it match?: False
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: vernon
# the matched words are (inorder): ['vernon', 'vernon']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: mitchell
# the matched words are (inorder): ['mitchell', 'kimmell']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: converse
# the matched words are (inorder): ['cities', 'college']
# did it match?: False
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: goshen
# the matched words are (inorder): ['goshen', 'corner']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: wadesville
# the matched words are (inorder): ['wadesville', 'markleville']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: salem
# the matched words are (inorder): ['selvin', 'sheldon']
# did it match?: False
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: brownsburg
# the matched words are (inorder): ['boonville', 'brownstown']
# did it match?: False
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: shown
# the matched words are (inorder): ['shown', 'brown']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: jackson
# the matched words are (inorder): ['jackson', 'jackson']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: morristown
# the matched words are (inorder): ['morton', 'morristown']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: portion
# the matched words are (inorder): ['portion', '"otoo"']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: midland
# the matched words are (inorder): ['midland', 'holland']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: fort
# the matched words are (inorder): ['fort', 'fort']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: eaton
# the matched words are (inorder): ['canton', 'benton']
# did it match?: False
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: addyston
# the matched words are (inorder): ['addyston', 'madison']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: creek
# the matched words are (inorder): ['creek', 'crete']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: kimmell
# the matched words are (inorder): ['linden', 'warren']
# did it match?: False
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: farm
# the matched words are (inorder): ['farm', 'frankton']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: grove
# the matched words are (inorder): ['grove', 'grove']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: lake
# the matched words are (inorder): ['lake', 'lake']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: wilbur
# the matched words are (inorder): ['walton', 'wilbur']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: bryantsburg
# the matched words are (inorder): ['roanoke', 'wawasee']
# did it match?: False
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: point
# the matched words are (inorder): ['point', 'point']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: reynolds
# the matched words are (inorder): ['newton', 'newport']
# did it match?: False
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ...
# Original image:
# IoU matched word is: perrysville
# the matched words are (inorder): ['perrysville', 'henryville']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: galien
# the matched words are (inorder): ['clinton', 'linden']
# did it match?: False
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: rome
# the matched words are (inorder): ['rome', 'roann']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: albany
# the matched words are (inorder): ['albany', 'albany']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: dixie
# the matched words are (inorder): ['mile', 'dixie']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: haute
# the matched words are (inorder): ['haute', 'prairie']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: alexandria
# the matched words are (inorder): ['alexandria', 'sedalia']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: state
# the matched words are (inorder): ['state', 'state']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: young
# the matched words are (inorder): ['young', 'youno']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: thru
# the matched words are (inorder): ['terre', 'wert']
# did it match?: False
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: dunlapsville
# the matched words are (inorder): ['medaryville', 'wadesville']
# did it match?: False
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: hatchery
# the matched words are (inorder): ['hatchery', 'hatchery']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: farmersburg
# the matched words are (inorder): ['burnettsville', 'rumsey']
# did it match?: False
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: anderson
# the matched words are (inorder): ['anderson', 'henderson']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: atlantic
# the matched words are (inorder): ['atlantic', 'atlantic']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: kendallville
# the matched words are (inorder): ['greenville', 'greenville']
# did it match?: False
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: cicero
# the matched words are (inorder): ['creek', 'crete']
# did it match?: False
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: black
# the matched words are (inorder): ['clinton', 'linton']
# did it match?: False
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: game
# the matched words are (inorder): ['game', 'game']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: north
# the matched words are (inorder): ['north', 'north']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: point
# the matched words are (inorder): ['point', 'point']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: york
# the matched words are (inorder): ['york', 'york']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: pigeon
# the matched words are (inorder): ['pigeon', 'paxton']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: alvin
# the matched words are (inorder): ['alvin', 'david']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: kinderhook
# the matched words are (inorder): ['angola', 'manilla']
# did it match?: False
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: nashville
# the matched words are (inorder): ['nashville', 'haysville']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: secondary
# the matched words are (inorder): ['secondary', 'star']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: martinsville
# the matched words are (inorder): ['martinsville', 'martinsville']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: made
# the matched words are (inorder): ['made', 'mace']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: sedalia
# the matched words are (inorder): ['sedalia', 'scale']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: seymour
# the matched words are (inorder): ['seymour', 'newtown']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: preserve
# the matched words are (inorder): ['preserve', 'preserve']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: miami
# the matched words are (inorder): ['miami', 'main']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: coatesville
# the matched words are (inorder): ['coatesville', 'centerville']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: roads
# the matched words are (inorder): ['ross', 'roads']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: valley
# the matched words are (inorder): ['valley', 'valley']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: independence
# the matched words are (inorder): ['palestine', 'independence']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: ladoga
# the matched words are (inorder): ['ladoga', 'raccoon']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# IoU matched word is: brown
# the matched words are (inorder): ['brown', 'crown']
# did it match?: True
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
