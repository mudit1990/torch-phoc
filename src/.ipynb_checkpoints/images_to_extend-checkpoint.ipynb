# %%
'''
The notebook takes all the images & words in a Map, creates word variations, 
runs phoc and gets the closest match to every clip in the map. 
Based on the matched word variation we get the direction the clip should 
be extended in and store it in a separate file. Below cells also contain
some analysis on how phoc performs, the top 10 neighbors etc
'''

import argparse
import logging

import numpy as np
import torch.autograd
import torch.cuda
import torch.nn as nn
import torch.optim
from torch.utils.data import DataLoader
from tqdm import tqdm_notebook as tqdm
import random

import copy
from datasets.maps_alt import MAPSDataset

#from cnn_ws.transformations.homography_augmentation import HomographyAugmentation
from cnn_ws.losses.cosine_loss import CosineLoss

from cnn_ws.models.myphocnet import PHOCNet
from cnn_ws.evaluation.retrieval import map_from_feature_matrix, map_from_query_test_feature_matrices
from torch.utils.data.dataloader import _DataLoaderIter as DataLoaderIter
from torch.utils.data.sampler import WeightedRandomSampler

from cnn_ws.utils.save_load import my_torch_save, my_torch_load

#import matplotlib.pyplot as plt

# %%
model_path = 'models/PHOCNet_Nov13.pt' # path of the phoc model to use
# the set of maps the code will be run on
A = ['D0042-1070001','D0042-1070002','D0042-1070006','D0042-1070007','D0117-5755018','D0117-5755035','D0117-5755036']
word_filter_len = 1 # only words above this length are considered valid
max_var_len = 1

# %%
if not torch.cuda.is_available():
    logger.warning('Could not find CUDA environment, using CPU mode')
    gpu_id = None
else:
    gpu_id = [0]
#torch.cuda.get_device_name(gpu_id[0])
pass

# %%
model_ = torch.load(model_path)
cnn = model_.module#list(model_.named_parameters())
if gpu_id is not None:
        if len(gpu_id) > 1:
            cnn = nn.DataParallel(cnn, device_ids=gpu_id)
            cnn.cuda()
        else:
            cnn.cuda(gpu_id[0])
cnn.training = False

# %%
from strlocale import BasicLocale

def clean_words(words):
    lc = BasicLocale()
    for i, w in enumerate(words):
        try:
            words[i] = lc.represent(w).encode('ascii',errors='ignore')
        except:
            words[i] = w
    return words

def load_and_transform(map_name):
    images = np.load('/mnt/nfs/work1/696ds-s18/mbhargava/detection_outputs_ready_for_test/ray_regions/org_clips/'+map_name+'.npy')
    words = np.load('/mnt/nfs/work1/696ds-s18/mbhargava/detection_outputs_ready_for_test/ray_labels/org_clips/'+map_name+'.npy')
    # images = np.load('../../../ProcessedData/original_images_nopad_'+map_name+'.tiff.npy')
    # words = np.load('../../../ProcessedData/original_words_nopad_'+map_name+'.tiff.npy')
    images = np.transpose(images, (0,3,1,2))
    words = clean_words(words)
    print 'Images Shape ', images.shape
    print 'Words Shape ', words.shape
    return images, words

# %%
def gen_img_phoc_embs(cnn, images):
    outputs = []
    for i in tqdm(range(len(images)), ascii=True, desc='Converting Images to Embeddings'):
        word_img = images[i]
        word_img = 1 - word_img.astype(np.float32) / 255.0
        word_img = word_img.reshape((1,) + word_img.shape)
        word_img = torch.from_numpy(word_img).float()
        word_img = word_img.cuda(gpu_id[0])
        word_img = torch.autograd.Variable(word_img)
        output = torch.sigmoid(cnn(word_img))
        output = output.data.cpu().numpy().flatten()
        outputs.append(output)
    return outputs

# %%
from cnn_ws.string_embeddings.phoc import build_phoc_descriptor

def insert_dict_set(dct, key, val):
    if key not in dct:
        dct[key] = set()
    dct[key].add(val)
    
# the method defines the rules to handle multiple dir associated with a given word
# returns conf_words which is a set of word_var where this confusion exists
# word_var: dictionary from word -> chosen_dir. Incase a word has multiple dir
# the following preference order is followed 0 > (1,-1) > (2,-2) > (3,-3) ...
def handle_word_conf(comp_word_var):
    word_var = {}
    conf_words = set()
    for var in comp_word_var.keys():
        dirs = np.array(list(comp_word_var[var]))
        if(len(dirs) == 1):
            word_var[var] = dirs[0]
        else:
            conf_words.add(var)
            idx = np.argmin(np.abs(dirs))
            word_var[var] = dirs[idx]
    return word_var, conf_words

# function to create word variations
# word_var is a dictionary that contains all variations as key and 0,1,-1 as value
# 0 denotes the root word, -1 denotes var = root_word[:-1], +1 denotes var = root_word[1:]
# root_word_var is a dict that stores original_word => all_variations
# enable_conf: boolean flag that controls if the confusion logic should be used.
# when enabled if a word is a root word as well as a word variation (happens if root words ar rand and grand)
# it marks it as to be extended and also stores it in the confusion list
def create_word_variations(words, enable_conf=False):
    word_var = {}
    root_word_var = {}
    # create the root word variation dict and set word_var as -1 or +1
    for w in words:
        root_var_list = [w, w.lower(), w.upper(), w.capitalize()]
        var_set = set()
        for var in root_var_list:
            for l in range(1,max_var_len+1):
                if len(w) <= l:
                    continue
                insert_dict_set(word_var, var, 0)
                insert_dict_set(word_var, var[l:], l)
                insert_dict_set(word_var, var[:-l], -l)
                var_set.add(var)
                var_set.add(var[l:])
                var_set.add(var[:-l])
        root_word_var[w] = var_set
    word_var, conf_words = handle_word_conf(word_var)
    return word_var, root_word_var, conf_words

def gen_text_phoc_embs(words):
    word_strings = words
    unigrams = [chr(i) for i in range(ord('&'), ord('&')+1) + range(ord('A'), ord('Z')+1) + \
                    range(ord('a'), ord('z') + 1) + range(ord('0'), ord('9') + 1)]
    bigram_levels = None
    bigrams = None
    phoc_unigram_levels=(1, 2, 4, 8)
    
    word_var_dir, root_word_var, conf_words = create_word_variations(word_strings, enable_conf=True)
    
    embedding = build_phoc_descriptor(words=word_strings,
                                  phoc_unigrams=unigrams,
                                  bigram_levels=bigram_levels,
                                  phoc_bigrams=bigrams,
                                  unigram_levels=phoc_unigram_levels)

    word_var_strings = word_var_dir.keys()
    embedding_var = build_phoc_descriptor(words=word_var_strings,
                                  phoc_unigrams=unigrams,
                                  bigram_levels=bigram_levels,
                                  phoc_bigrams=bigrams,
                                  unigram_levels=phoc_unigram_levels)
    
    return (embedding, embedding_var, word_var_strings, word_var_dir, root_word_var, conf_words)

# %%
# the new report matches method that handles variations
from scipy.spatial.distance import cdist, pdist, squareform
def report_matches_with_variations(outputs, embedding_var, matching, word_strings, 
                                   word_var_strings, word_var_dir, root_word_var, k, length):
    # length sorting stuff
    qualified_ids = [x for x in range(len(word_strings)) if len(word_strings[x]) > length]
    outputs = np.array(outputs)
    word_strings = np.array(word_strings)
    outputs = list(outputs[qualified_ids])
    word_strings = list(word_strings[qualified_ids])
    
    # same stuff for variations
#     qualified_ids_vars = [x for x in range(len(word_var_strings)) if len(word_var_strings[x]) > (length)]
#     embedding_var = np.array(embedding_var)
#     word_var_strings = np.array(word_var_strings)
#     embedding_var = list(embedding_var[qualified_ids_vars])
#     word_var_strings = list(word_var_strings[qualified_ids_vars])
    
    # the real computation
    dist_mat = cdist(XA=outputs, XB=embedding_var, metric=matching)
    retrieval_indices = np.argsort(dist_mat, axis=1)
    q = retrieval_indices[:,:k]
    count = 0
    matched_words = []
    img_dir = []
    words_len = []
    min_ext_len = 3
    # get all matched words
    for i in range(len(q)):
        matched = []
        for j in q[i]:
            matched.append(word_var_strings[j])
            curr_len = len(word_var_strings[j])
            curr_dir = word_var_dir[word_var_strings[j]]
            # don't extend an image if its ground truth length is less than min_ext_len
            if len(word_strings[i]) < min_ext_len:
                curr_dir = 0
            words_len.append(curr_len + abs(curr_dir))
            img_dir.append(curr_dir)
        matched_words.append(matched)
    
    # calculate accuracies
    for i in range(len(word_strings)):
        #print word_strings[i]
        if word_strings[i].lower() in [mw.lower() for mw in matched_words[i]]:
            count = count+1
        else:
            for w in matched_words[i]:
                if w in root_word_var[word_strings[i]]:
                    count = count+1
                    break

    return (count, matched_words, qualified_ids, img_dir, words_len, outputs, word_strings, dist_mat)

# %%
# the old original report matches method
from scipy.spatial.distance import cdist, pdist, squareform
def report_matches(outputs, embedding, matching, word_strings, k, length):
    # length sorting stuff
    qualified_ids = [x for x in range(len(word_strings)) if len(word_strings[x]) > length]
    outputs = np.array(outputs)
    embedding = np.array(embedding)
    word_strings = np.array(word_strings)
    outputs = list(outputs[qualified_ids])
    embedding = list(embedding[qualified_ids])
    word_strings = list(word_strings[qualified_ids])
    # the real computation
    dist_mat = cdist(XA=outputs, XB=embedding, metric=matching)
    retrieval_indices = np.argsort(dist_mat, axis=1)
    q = retrieval_indices[:,:k]
    count = 0
    matched_words = []
    # get all matched words
    for i in range(len(q)):
        matched = []
        for j in q[i]:
            matched.append(word_strings[j])
        matched_words.append(matched)
    
    for i in range(len(word_strings)):
        if word_strings[i].lower() in [mw.lower() for mw in matched_words[i]]:
            count = count+1

    return (count, matched_words, outputs, embedding, word_strings, qualified_ids, dist_mat)

# %%
# given the image name, this driver function computes the following
# 1. loads the words and images and transforms them based on image name
# 2. generates embeddings for images using the cnn model
# 3. gets the original and variation embeddings
# 4. generate report with word variations (prints accuracy)
# 5. generate report original (prints accuracy)
# 6. returns the image_dir_info that needs to be saved as numpy files
def image_ext_with_word_var(map_name, cnn, global_stats):
    images, words = load_and_transform(map_name)
    img_phoc_embs = gen_img_phoc_embs(cnn, images)
    print 'image shape before',images.shape
    embedding, embedding_var, word_var_strings, word_var_dir, root_word_var, conf_set = gen_text_phoc_embs(words)
    print set([s.lower() for s in conf_set])
    original_report = report_matches(img_phoc_embs, embedding, 'cosine', words, 1, word_filter_len)
    print 'image_shape_after_var', np.array(original_report[2]).shape
    global_stats['correct_original'] += original_report[0]
    print 'Original Accuracy ', str(original_report[0]/float(len(original_report[4])))
    word_var_report = report_matches_with_variations(img_phoc_embs, embedding_var,'cosine', words, \
                                                     word_var_strings, word_var_dir, root_word_var, 1, word_filter_len)
    print 'image_shape_after_var', np.array(word_var_report[5]).shape
    global_stats['correct_word_var'] += word_var_report[0]
    print 'Accuracy With Word Variations ', str(word_var_report[0]/float(len(word_var_report[4])))
    global_stats['total'] += len(word_var_report[4])
    img_dir_info = np.array([word_var_report[2], word_var_report[3], word_var_report[4]])
    return img_dir_info, word_var_report[6], conf_set, original_report, word_var_report

# %%
original_report = None
word_var_report = None
global_stats = {'correct_original':0, 'correct_word_var':0, 'total':0}
for i in tqdm(range(len(A)), ascii=True, desc = 'Main Iteration'):
    print A[i]
    img_dir_info, words, conf_words, original_report, word_var_report = image_ext_with_word_var(A[i], cnn, global_stats)
    np.save('/mnt/nfs/work1/696ds-s18/mbhargava/images_to_extend/final_runs/ray_output_normal/image_dir_'+A[i]+'.npy', img_dir_info)
    np.save('/mnt/nfs/work1/696ds-s18/mbhargava/images_to_extend/final_runs/ray_output_normal/image_labels_'+A[i]+'.npy', words)
print 'Accuracy Original', global_stats['correct_original']/float(global_stats['total'])
print 'Accuracy With Word Variations', global_stats['correct_word_var']/float(global_stats['total'])
# Out:
# HBox(children=(IntProgress(value=0, description=u'Main Iteration', max=1), HTML(value=u'')))
# D0042-1070001
# Images Shape  (1192, 3, 135, 487)
# Words Shape  (1192,)
# SEJveChjaGlsZHJlbj0oSW50UHJvZ3Jlc3ModmFsdWU9MCwgZGVzY3JpcHRpb249dSdDb252ZXJ0aW5nIEltYWdlcyB0byBFbWJlZGRpbmdzJywgbWF4PTExOTIpLCBIVE1MKHZhbHVlPXUnJynigKY=
#  52%|█████▏    | 619/1192 [00:00<00:00, 6181.96it/s]
# image shape before (1192, 3, 135, 487)
# 100%|██████████| 1192/1192 [00:00<00:00, 4954.18it/s]
# 100%|██████████| 1805/1805 [00:00<00:00, 5381.66it/s]
# set(['and', 'ix', 'x', 'xi', 'xv', 'v', 'i', 'xii', 'vii', 'ii', 'an', 'xvi', 'xx', '1', 'xvii', 'viii', 'vi', '2', 'xxi', 'iv', 'iii'])
# image_shape_after_var (1069, 945)
# Original Accuracy  0.442469597755
# image_shape_after_var (1069, 945)
# Accuracy With Word Variations  0.499532273152
#
# Accuracy Original 0.442469597755
# Accuracy With Word Variations 0.499532273152

# %%
global_stats = {'correct_original':0, 'correct_word_var':0, 'total':0}
img_dir_info, words, conf_words, original_report, word_var_report = image_ext_with_word_var(A[0], cnn, global_stats)
print 'Accuracy Original', global_stats['correct_original']/float(global_stats['total'])
print 'Accuracy With Word Variations', global_stats['correct_word_var']/float(global_stats['total'])
# Out:
# Images Shape  (1199, 3, 135, 487)
# Words Shape  (1199,)
# SEJveChjaGlsZHJlbj0oSW50UHJvZ3Jlc3ModmFsdWU9MCwgZGVzY3JpcHRpb249dSdDb252ZXJ0aW5nIEltYWdlcyB0byBFbWJlZGRpbmdzJywgbWF4PTExOTkpLCBIVE1MKHZhbHVlPXUnJynigKY=
#  39%|███▉      | 472/1199 [00:00<00:00, 4719.10it/s]
# image shape before (1199, 3, 135, 487)
# 100%|██████████| 1199/1199 [00:00<00:00, 5181.57it/s]
# 100%|██████████| 1813/1813 [00:00<00:00, 6885.11it/s]
# set(['and', 'ix', 'x', 'xi', 'xv', 'v', 'i', 'xii', 'vii', 'ii', 'iv', 'xvi', 'xx', '1', 'xvii', 'viii', 'vi', '2', 'xxi', 'an', 'iii'])
# image_shape_after_var (1078, 945)
# Original Accuracy  0.440630797774
# image_shape_after_var (1078, 945)
# Accuracy With Word Variations  0.49814471243
# Accuracy Original 0.440630797774
# Accuracy With Word Variations 0.49814471243

# %%
count, matched_words, outputs, embedding, word_strings, qualified_ids, dist_mat = original_report
print(len(matched_words))
for i in range(len(matched_words)):
    if matched_words[i][0].lower() == word_strings[i].lower():
        print i, matched_words[i], word_strings[i]
# Out:
# 1069
# 0 ['ASHTABULA'] ASHTABULA
# 3 ['TUSKARAWAS'] TUSKARAWAS
# 31 ['MAHONING'] MAHONING
# 38 ['Land'] Land
# 39 ['BROWN'] BROWN
# 40 ['Gallipolis'] Gallipolis
# 42 ['October'] October
# 43 ['KNOX'] KNOX
# 44 ['Pomeroy'] Pomeroy
# 46 ['Cadiz'] Cadiz
# 47 ['Purchase'] Purchase
# 48 ['HARDIN'] HARDIN
# 50 ['LOGAN'] LOGAN
# 51 ['HENRY'] HENRY
# 52 ['eastern'] eastern
# 53 ['MEDINA'] MEDINA
# 54 ['Seat'] Seat
# 55 ['DARKE'] DARKE
# 56 ['ROSS'] ROSS
# 57 ['Kenton'] Kenton
# 58 ['London'] London
# 59 ['WOOD'] WOOD
# 60 ['Boundary'] Boundary
# 61 ['LAWRENCE'] LAWRENCE
# 62 ['General'] General
# 63 ['Georgetown'] Georgetown
# 64 ['FAYETTE'] FAYETTE
# 68 ['MUSKINGUM'] MUSKINGUM
# 69 ['Batavia'] Batavia
# 70 ['1866'] 1866
# 71 ['Comp'] Comp
# 72 ['CINCINNATI'] CINCINNATI
# 73 ['Land'] Land
# 74 ['WYANDOT'] WYANDOT
# 75 ['Medina'] Medina
# 76 ['CRAWFORD'] CRAWFORD
# 77 ['Perrysburg'] Perrysburg
# 80 ['Interior'] Interior
# 81 ['Purchase'] Purchase
# 82 ['CLARK'] CLARK
# 84 ['Office'] Office
# 85 ['and'] and
# 86 ['FULTON'] FULTON
# 87 ['Ironton'] Ironton
# 88 ['CHAMPAIGN'] CHAMPAIGN
# 89 ['Note'] Note
# 90 ['Railroads'] Railroads
# 91 ['Delaware'] Delaware
# 92 ['Portsmouth'] Portsmouth
# 93 ['Chillicothe'] Chillicothe
# 94 ['ATHENS'] ATHENS
# 96 ['Bellefontaine'] Bellefontaine
# 98 ['HOLMES'] HOLMES
# 99 ['State'] State
# 100 ['Carrolton'] Carrolton
# 101 ['Athens'] Athens
# 103 ['Springfield'] Springfield
# 105 ['Lebanon'] Lebanon
# 107 ['Chardon'] Chardon
# 108 ['Reserve'] Reserve
# 109 ['are'] are
# 110 ['Marysville'] Marysville
# 111 ['HOCKING'] HOCKING
# 113 ['and'] and
# 114 ['HURON'] HURON
# 115 ['Wilmington'] Wilmington
# 116 ['Land'] Land
# 117 ['LAKE'] LAKE
# 118 ['HANCOCK'] HANCOCK
# 119 ['abound'] abound
# 120 ['State'] State
# 122 ['Portage'] Portage
# 123 ['County'] County
# 124 ['and'] and
# 125 ['Paulding'] Paulding
# 127 ['Circleville'] Circleville
# 128 ['Findlay'] Findlay
# 129 ['WAYNE'] WAYNE
# 130 ['Akron'] Akron
# 131 ['generally'] generally
# 133 ['PREBLE'] PREBLE
# 134 ['Greenville'] Greenville
# 135 ['Troy'] Troy
# 137 ['Coal'] Coal
# 138 ['MEIGS'] MEIGS
# 139 ['MARION'] MARION
# 140 ['beds'] beds
# 141 ['thickness'] thickness
# 142 ['West'] West
# 143 ['Salt'] Salt
# 144 ['Kalida'] Kalida
# 145 ['NOBLE'] NOBLE
# 146 ['Eaton'] Eaton
# 147 ['Columbus'] Columbus
# 148 ['Hillsboro'] Hillsboro
# 150 ['CARROLL'] CARROLL
# 151 ['MIAMI'] MIAMI
# 152 ['GREENE'] GREENE
# 153 ['COSHOCTON'] COSHOCTON
# 155 ['Jefferson'] Jefferson
# 156 ['FAIRFIELD'] FAIRFIELD
# 158 ['Land'] Land
# 160 ['2d'] 2d
# 161 ['Ashland'] Ashland
# 162 ['frequent'] frequent
# 163 ['HARRISON'] HARRISON
# 164 ['Zanesville'] Zanesville
# 166 ['the'] the
# 167 ['PERRY'] PERRY
# 168 ['SANDUSKY'] SANDUSKY
# 169 ['SENECA'] SENECA
# 170 ['Cleveland'] Cleveland
# 171 ['Lime'] Lime
# 172 ['of'] of
# 173 ['XX'] XX
# 174 ['Virginia'] Virginia
# 178 ['VAN'] VAN
# 179 ['and'] and
# 181 ['HAMILTON'] HAMILTON
# 182 ['Woodsfield'] Woodsfield
# 183 ['Norwalk'] Norwalk
# 185 ['Iron'] Iron
# 186 ['Urbana'] Urbana
# 187 ['Xenia'] Xenia
# 188 ['abound'] abound
# 189 ['XVII'] XVII
# 190 ['Fire'] Fire
# 193 ['Warren'] Warren
# 194 ['PUTNAM'] PUTNAM
# 195 ['PICKAWAY'] PICKAWAY
# 196 ['Canton'] Canton
# 200 ['LICKING'] LICKING
# 201 ['XIX'] XIX
# 202 ['Millersburg'] Millersburg
# 203 ['part'] part
# 205 ['Celina'] Celina
# 206 ['Philadelphia'] Philadelphia
# 209 ['Wooster'] Wooster
# 210 ['Raven'] Raven
# 212 ['Union'] Union
# 214 ['XVI'] XVI
# 216 ['Mansfield'] Mansfield
# 217 ['Bryan'] Bryan
# 219 ['in'] in
# 220 ['IX'] IX
# 221 ['Bucyrus'] Bucyrus
# 222 ['13'] 13
# 224 ['SHELBY'] SHELBY
# 225 ['STATE'] STATE
# 228 ['GEAUGA'] GEAUGA
# 231 ['Jackson'] Jackson
# 232 ['the'] the
# 233 ['13'] 13
# 234 ['STARK'] STARK
# 235 ['Arthur'] Arthur
# 236 ['10'] 10
# 237 ['OHIO'] OHIO
# 238 ['Mt'] Mt
# 241 ['Painesville'] Painesville
# 243 ['14'] 14
# 244 ['ERIE'] ERIE
# 246 ['Logan'] Logan
# 248 ['Land'] Land
# 251 ['WAYNE'] WAYNE
# 252 ['IV'] IV
# 254 ['17'] 17
# 257 ['12'] 12
# 263 ['Commissioner'] Commissioner
# 270 ['13'] 13
# 274 ['Explanations'] Explanations
# 275 ['Office'] Office
# 276 ['Van'] Van
# 277 ['Wert'] Wert
# 280 ['14'] 14
# 282 ['15'] 15
# 285 ['XII'] XII
# 286 ['10'] 10
# 287 ['20'] 20
# 290 ['12'] 12
# 291 ['the'] the
# 292 ['New'] New
# 295 ['16'] 16
# 297 ['FRANKLIN'] FRANKLIN
# 302 ['23'] 23
# 306 ['Ottokee'] Ottokee
# 308 ['12'] 12
# 309 ['17'] 17
# 310 ['IX'] IX
# 311 ['11'] 11
# 314 ['12'] 12
# 315 ['throughout'] throughout
# 317 ['11'] 11
# 323 ['OF'] OF
# 325 ['DEFIANCE'] DEFIANCE
# 327 ['LORAIN'] LORAIN
# 330 ['15'] 15
# 331 ['13'] 13
# 332 ['PAULDING'] PAULDING
# 334 ['10'] 10
# 335 ['11'] 11
# 337 ['CUYAHOGA'] CUYAHOGA
# 338 ['12'] 12
# 340 ['21'] 21
# 341 ['JACKSON'] JACKSON
# 342 ['UNION'] UNION
# 344 ['MANSFIELD'] MANSFIELD
# 351 ['Columbus'] COLUMBUS
# 354 ['Maumee'] Maumee
# 355 ['GREAT'] GREAT
# 356 ['Bay'] Bay
# 357 ['ATLANTIC'] ATLANTIC
# 358 ['Scioto'] SCIOTO
# 360 ['CHICAGO'] CHICAGO
# 367 ['MONTGOMERY'] MONTGOMERY
# 368 ['TOLEDO'] TOLEDO
# 371 ['WESTERN'] WESTERN
# 378 ['CINCIN'] CINCIN
# 386 ['DAYTON'] DAYTON
# 387 ['MORROW'] MORROW
# 390 ['HAMILTON'] HAMILTON
# 393 ['RIVER'] RIVER
# 405 ['ASHTABULA'] ASHTABULA
# 438 ['TUSKARAWAS'] TUSKARAWAS
# 452 ['GUERNSEY'] GUERNSEY
# 461 ['CENTRAL'] CENTRAL
# 462 ['Troy'] Troy
# 463 ['Mily'] Mily
# 465 ['Sandusky'] Sandusky
# 471 ['13'] 13
# 473 ['MIAMI'] MIAMI
# 474 ['12'] 12
# 477 ['Somerset'] Somerset
# 478 ['FAYETTE'] FAYETTE
# 481 ['West'] West
# 482 ['Comp'] Comp
# 483 ['1866'] 1866
# 485 ['Warren'] Warren
# 486 ['IX'] IX
# 487 ['12'] 12
# 488 ['13'] 13
# 489 ['18'] 18
# 496 ['IX'] IX
# 499 ['15'] 15
# 501 ['Urbana'] Urbana
# 502 ['Canfield'] Canfield
# 504 ['Gallipolis'] Gallipolis
# 506 ['12'] 12
# 507 ['11'] 11
# 508 ['10'] 10
# 509 ['Pomeroy'] Pomeroy
# 516 ['Union'] Union
# 519 ['MEIGS'] MEIGS
# 523 ['16'] 16
# 525 ['16'] 16
# 527 ['23'] 23
# 528 ['WILMINGTON'] WILMINGTON
# 529 ['ATLANTIC'] ATLANTIC
# 530 ['Columbus'] COLUMBUS
# 532 ['Bay'] Bay
# 537 ['WESTERN'] WESTERN
# 538 ['CINCIN'] CINCIN
# 539 ['WASHINGTON'] WASHINGTON
# 541 ['WESTERN'] WESTERN
# 546 ['15'] 15
# 547 ['14'] 14
# 549 ['13'] 13
# 560 ['COLUMBUS'] COLUMBUS
# 561 ['GREAT'] GREAT
# 564 ['SCIOTO'] SCIOTO
# 576 ['11'] 11
# 595 ['UNION'] UNION
# 596 ['MANSFIELD'] MANSFIELD
# 604 ['Scioto'] Scioto
# 607 ['RIVER'] RIVER
# 608 ['LUCAS'] LUCAS
# 609 ['OHIO'] OHIO
# 610 ['BUTLER'] BUTLER
# 611 ['MICHIGAN'] MICHIGAN
# 615 ['DAYTON'] DAYTON
# 628 ['DAYTON'] DAYTON
# 636 ['IX'] IX
# 641 ['15'] 15
# 666 ['OHIO'] OHIO
# 674 ['JACKSON'] JACKSON
# 675 ['GUERNSEY'] GUERNSEY
# 679 ['COLUMBIANA'] COLUMBIANA
# 682 ['19'] 19
# 683 ['Troy'] Troy
# 685 ['13'] 13
# 691 ['12'] 12
# 693 ['HOCKING'] HOCKING
# 694 ['abound'] abound
# 695 ['LOGAN'] LOGAN
# 697 ['throughout'] throughout
# 698 ['CRAWFORD'] CRAWFORD
# 700 ['CARROLL'] CARROLL
# 701 ['Carrolton'] Carrolton
# 702 ['Chardon'] Chardon
# 703 ['HARDIN'] HARDIN
# 705 ['VAN'] VAN
# 706 ['HURON'] HURON
# 707 ['Reserve'] Reserve
# 708 ['WERT'] WERT
# 709 ['Note'] Note
# 711 ['Land'] Land
# 712 ['Land'] Land
# 713 ['COSHOCTON'] COSHOCTON
# 714 ['Purchase'] Purchase
# 715 ['Jefferson'] Jefferson
# 716 ['Land'] Land
# 718 ['beds'] beds
# 719 ['LORAIN'] LORAIN
# 720 ['DEFIANCE'] DEFIANCE
# 721 ['GREENE'] GREENE
# 722 ['WILLIAMS'] WILLIAMS
# 723 ['Boundary'] Boundary
# 724 ['KNOX'] KNOX
# 725 ['are'] are
# 726 ['PAULDING'] PAULDING
# 728 ['Elyria'] Elyria
# 729 ['MEDINA'] MEDINA
# 730 ['Paulding'] Paulding
# 731 ['of'] of
# 732 ['Raven'] Raven
# 733 ['LAKE'] LAKE
# 734 ['HANCOCK'] HANCOCK
# 735 ['PUTNAM'] PUTNAM
# 736 ['HIGHLAND'] HIGHLAND
# 737 ['Norwalk'] Norwalk
# 738 ['HAMILTON'] HAMILTON
# 740 ['NOBLE'] NOBLE
# 741 ['State'] State
# 742 ['HOLMES'] HOLMES
# 743 ['October'] October
# 744 ['ZANESY'] ZANESY
# 745 ['WOOD'] WOOD
# 747 ['ROSS'] ROSS
# 748 ['CUYAHOGA'] CUYAHOGA
# 749 ['ALLEN'] ALLEN
# 750 ['and'] and
# 751 ['MONROE'] MONROE
# 754 ['and'] and
# 756 ['Pomeroy'] Pomeroy
# 757 ['1866'] 1866
# 758 ['CINCINNATI'] CINCINNATI
# 759 ['Kalida'] Kalida
# 760 ['WYANDOT'] WYANDOT
# 761 ['Interior'] Interior
# 763 ['Office'] Office
# 764 ['General'] General
# 766 ['and'] and
# 767 ['Kenton'] Kenton
# 768 ['VINTON'] VINTON
# 769 ['Logan'] Logan
# 770 ['Department'] Department
# 771 ['part'] part
# 772 ['Portsmouth'] Portsmouth
# 773 ['thickness'] thickness
# 774 ['Lebanon'] Lebanon
# 775 ['BROWN'] BROWN
# 777 ['the'] the
# 779 ['HENRY'] HENRY
# 780 ['HARRISON'] HARRISON
# 781 ['frequent'] frequent
# 782 ['Medina'] Medina
# 783 ['WAYNE'] WAYNE
# 784 ['Marysville'] Marysville
# 785 ['Painesville'] Painesville
# 786 ['Athens'] Athens
# 787 ['PICKAWAY'] PICKAWAY
# 789 ['Eaton'] Eaton
# 790 ['MUSKINGUM'] MUSKINGUM
# 791 ['and'] and
# 793 ['STARK'] STARK
# 794 ['Bryan'] Bryan
# 795 ['Cleveland'] Cleveland
# 799 ['State'] State
# 800 ['MORGAN'] MORGAN
# 801 ['Salt'] Salt
# 802 ['MEIGS'] MEIGS
# 803 ['in'] in
# 804 ['Iron'] Iron
# 805 ['SHELBY'] SHELBY
# 806 ['Celina'] Celina
# 810 ['PORTAGE'] PORTAGE
# 811 ['PITTSBURG'] PITTSBURG
# 813 ['13'] 13
# 814 ['Ottokee'] Ottokee
# 815 ['Gallipolis'] Gallipolis
# 816 ['CLARK'] CLARK
# 817 ['Land'] Land
# 818 ['County'] County
# 819 ['Circleville'] Circleville
# 820 ['SENECA'] SENECA
# 821 ['Cadiz'] Cadiz
# 823 ['AUGLAISE'] AUGLAISE
# 827 ['London'] London
# 828 ['Urbana'] Urbana
# 830 ['Akron'] Akron
# 832 ['2d'] 2d
# 833 ['DARKE'] DARKE
# 835 ['Findlay'] Findlay
# 837 ['FAYETTE'] FAYETTE
# 838 ['TRUMBULL'] TRUMBULL
# 840 ['Ironton'] Ironton
# 842 ['LAWRENCE'] LAWRENCE
# 843 ['Military'] Military
# 844 ['MARION'] MARION
# 845 ['23'] 23
# 849 ['in'] in
# 850 ['PERRY'] PERRY
# 851 ['Comp'] Comp
# 859 ['Zanesville'] Zanesville
# 860 ['XX'] XX
# 862 ['Wooster'] Wooster
# 863 ['Symmess'] Symmess
# 868 ['Mansfield'] Mansfield
# 871 ['Mily'] Mily
# 872 ['Columbus'] Columbus
# 873 ['the'] the
# 874 ['14'] 14
# 881 ['MIAMI'] MIAMI
# 883 ['Chillicothe'] Chillicothe
# 884 ['BELMONT'] BELMONT
# 885 ['Perrysburg'] Perrysburg
# 893 ['12'] 12
# 894 ['Xenia'] Xenia
# 895 ['XIX'] XIX
# 902 ['Woodsfield'] Woodsfield
# 904 ['Van'] Van
# 908 ['ERIE'] ERIE
# 911 ['Hillsboro'] Hillsboro
# 913 ['OF'] OF
# 915 ['17'] 17
# 918 ['West'] West
# 919 ['Bay'] Bay
# 920 ['14'] 14
# 926 ['Cartography'] Cartography
# 929 ['Ashland'] Ashland
# 933 ['11'] 11
# 934 ['11'] 11
# 942 ['14'] 14
# 951 ['Mt'] Mt
# 954 ['Delaware'] Delaware
# 956 ['Defiance'] Defiance
# 957 ['13'] 13
# 961 ['SANDUSKY'] SANDUSKY
# 962 ['FAIRFIELD'] FAIRFIELD
# 972 ['Jackson'] Jackson
# 973 ['Philadelphia'] Philadelphia
# 976 ['12'] 12
# 982 ['23'] 23
# 984 ['Canton'] Canton
# 986 ['OHIO'] OHIO
# 988 ['Canfield'] Canfield
# 989 ['PURCHASE'] PURCHASE
# 990 ['TOLEDO'] TOLEDO
# 991 ['BUTLER'] BUTLER
# 992 ['CINCIN'] CINCIN
# 994 ['OHIO'] OHIO
# 996 ['SYMMESS'] SYMMESS
# 1002 ['Maumee'] Maumee
# 1005 ['RIVER'] RIVER
# 1008 ['LUCAS'] LUCAS
# 1010 ['CHICAGO'] CHICAGO
# 1014 ['ASHLAND'] ASHLAND
# 1016 ['Scioto'] Scioto
# 1019 ['SUMMIT'] SUMMIT
# 1031 ['MERCER'] MERCER
# 1045 ['MORROW'] MORROW
# 1046 ['DAYTON'] DAYTON
# 1051 ['12'] 12
# 1060 ['DAYTON'] DAYTON

# %%
sorted_dist = np.argsort(dist_mat, axis=1)

# %%
images, words = load_and_transform(A[0])
# Out:
# Images Shape  (1192, 3, 135, 487)
# Words Shape  (1192,)

# %%
def top_10_unique(words):
    word_set = set()
    un_words = []
    for w in words:
        if w in word_set:
            continue
        un_words.append(w)
        word_set.add(w)
        if len(un_words) == 10:
            return un_words
    return un_words

# %%
import matplotlib.pyplot as plt
# analysis of land image
img_ids = set([38, 73, 116, 158, 248, 711, 712, 716, 817])
for i in range(len(matched_words)):
    if i not in img_ids:
        continue
    print "************************************************************************"
    print "************************************************************************"
    print "Original image:"
    q = np.transpose(images[qualified_ids[i]],(1,2,0))
    plt.imshow(q)
    plt.show()
    #print "the matched words are (inorder): "+str(matched_words[i])
    #print "the gound truth is:" + str(word_strings[i])
    nr_words = [word_strings[j] for j in sorted_dist[i][:100]]
    print "top 10 matches are: ", top_10_unique(nr_words)
    print "------------------------------------------------------------------------"
    print "------------------------------------------------------------------------"
# Out:
# ************************************************************************
# ************************************************************************
# Original image:
# top 10 matches are:  ['Land', 'Lebanon', 'Logan', 'Van', 'London', 'Lima', 'Eaton', 'abound', 'Raven', 'Salt']
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# top 10 matches are:  ['Land', 'and', 'London', 'Lebanon', 'abound', 'Canfield', 'Van', 'Mansfield', 'Chardon', 'Logan']
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# top 10 matches are:  ['Land', 'Lebanon', 'and', 'abound', 'Van', 'London', 'Chardon', 'Logan', 'Lima', 'Ashland']
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# top 10 matches are:  ['Land', 'Lebanon', 'and', 'abound', 'Van', 'London', 'Chardon', 'Logan', 'Ashland', 'Cadiz']
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# top 10 matches are:  ['Land', 'Lebanon', 'and', 'abound', 'Van', 'London', 'Chardon', 'Logan', 'Lima', 'Ashland']
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# top 10 matches are:  ['Land', 'Lebanon', 'and', 'abound', 'Van', 'London', 'Chardon', 'Logan', 'Lima', 'Ashland']
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# top 10 matches are:  ['Land', 'Lebanon', 'and', 'abound', 'Van', 'London', 'Chardon', 'Logan', 'Lima', 'Ashland']
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# top 10 matches are:  ['Land', 'and', 'Lebanon', 'abound', 'Van', 'London', 'Chardon', 'Logan', 'Ashland', 'Eaton']
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# top 10 matches are:  ['Land', 'Lebanon', 'abound', 'and', 'London', 'Chardon', 'Van', 'Logan', 'Eaton', 'Wapakoneta']
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------

# %%
import matplotlib.pyplot as plt
# analysis of logan image
img_ids = set([50,246,695,769])
for i in range(len(matched_words)):
    if i not in img_ids:
        continue
    print "************************************************************************"
    print "************************************************************************"
    print "Original image:"
    q = np.transpose(images[qualified_ids[i]],(1,2,0))
    plt.imshow(q)
    plt.show()
    print "the matched words are (inorder): "+str(matched_words[i])
    print "the gound truth is:" + str(word_strings[i])
    print "top 10 matches are: ", [word_strings[j] for j in sorted_dist[i][:10]]
    print "------------------------------------------------------------------------"
    print "------------------------------------------------------------------------"
# Out:
# ************************************************************************
# ************************************************************************
# Original image:
# the matched words are (inorder): ['LOGAN']
# the gound truth is:LOGAN
# top 10 matches are:  ['LOGAN', 'LOGAN', 'LORAIN', 'LORAIN', 'LORAIN', 'LORAIN', 'MORGAN', 'COLUMBIANA', 'COLUMBIANA', 'COLUMBIANA']
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# the matched words are (inorder): ['Logan']
# the gound truth is:Logan
# top 10 matches are:  ['Logan', 'Logan', 'Georgetown', 'Georgetown', 'Georgetown', 'Bryan', 'Bryan', 'Cartography', 'Lebanon', 'Lebanon']
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# the matched words are (inorder): ['LOGAN']
# the gound truth is:LOGAN
# top 10 matches are:  ['LOGAN', 'LOGAN', 'LORAIN', 'LORAIN', 'LORAIN', 'LORAIN', 'MORGAN', 'COLUMBIANA', 'COLUMBIANA', 'COLUMBIANA']
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# the matched words are (inorder): ['Logan']
# the gound truth is:Logan
# top 10 matches are:  ['Logan', 'Logan', 'Cartography', 'Portage', 'Portage', 'Virginia', 'Virginia', 'Bryan', 'Bryan', 'Coal']
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------

# %%
import matplotlib.pyplot as plt
# analysis of 1866 image
img_ids = set([70, 483, 757])
for i in range(len(matched_words)):
    if i not in img_ids:
        continue
    print "************************************************************************"
    print "************************************************************************"
    print "Original image:"
    q = np.transpose(images[qualified_ids[i]],(1,2,0))
    plt.imshow(q)
    plt.show()
    print "the matched words are (inorder): "+str(matched_words[i])
    print "the gound truth is:" + str(word_strings[i])
    print "top 10 matches are: ", [word_strings[j] for j in sorted_dist[i][:10]]
    print "------------------------------------------------------------------------"
    print "------------------------------------------------------------------------"
# Out:
# ************************************************************************
# ************************************************************************
# Original image:
# the matched words are (inorder): ['1866']
# the gound truth is:1866
# top 10 matches are:  ['1866', '1866', '1866', '16', '16', '16', '16', '16', '16', '16']
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# the matched words are (inorder): ['1866']
# the gound truth is:1866
# top 10 matches are:  ['1866', '1866', '1866', '16', '16', '16', '16', '16', '16', '16']
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# the matched words are (inorder): ['1866']
# the gound truth is:1866
# top 10 matches are:  ['1866', '1866', '1866', '16', '16', '16', '16', '16', '16', '16']
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------

# %%
import matplotlib.pyplot as plt
# analysis of CRAWFORD image
img_ids = set([76, 698])
for i in range(len(matched_words)):
    if i not in img_ids:
        continue
    print "************************************************************************"
    print "************************************************************************"
    print "Original image:"
    q = np.transpose(images[qualified_ids[i]],(1,2,0))
    plt.imshow(q)
    plt.show()
    print "the matched words are (inorder): "+str(matched_words[i])
    print "the gound truth is:" + str(word_strings[i])
    print "top 10 matches are: ", [word_strings[j] for j in sorted_dist[i][:10]]
    print "------------------------------------------------------------------------"
    print "------------------------------------------------------------------------"
# Out:
# ************************************************************************
# ************************************************************************
# Original image:
# the matched words are (inorder): ['CRAWFORD']
# the gound truth is:CRAWFORD
# top 10 matches are:  ['CRAWFORD', 'CRAWFORD', 'CRAWFORD', 'FAIRFIELD', 'FAIRFIELD', 'FAIRFIELD', 'WOOD', 'WOOD', 'MANSFIELD', 'MANSFIELD']
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# the matched words are (inorder): ['CRAWFORD']
# the gound truth is:CRAWFORD
# top 10 matches are:  ['CRAWFORD', 'CRAWFORD', 'CRAWFORD', 'CARROLL', 'CARROLL', 'CARROLL', 'WOOD', 'WOOD', 'FAIRFIELD', 'FAIRFIELD']
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------

# %%
import matplotlib.pyplot as plt
# analysis of state image
img_ids = set([99, 120, 225, 741, 799])
for i in range(len(matched_words)):
    if i not in img_ids:
        continue
    print "************************************************************************"
    print "************************************************************************"
    print "Original image:"
    q = np.transpose(images[qualified_ids[i]],(1,2,0))
    plt.imshow(q)
    plt.show()
    print "the matched words are (inorder): "+str(matched_words[i])
    print "the gound truth is:" + str(word_strings[i])
    print "top 10 matches are: ", [word_strings[j] for j in sorted_dist[i][:10]]
    print "------------------------------------------------------------------------"
    print "------------------------------------------------------------------------"
# Out:
# ************************************************************************
# ************************************************************************
# Original image:
# the matched words are (inorder): ['State']
# the gound truth is:State
# top 10 matches are:  ['State', 'State', 'State', 'State', 'nolabelattached', 'nolabelattached', 'nolabelattached', 'nolabelattached', 'nolabelattached', 'nolabelattached']
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# the matched words are (inorder): ['State']
# the gound truth is:State
# top 10 matches are:  ['State', 'State', 'State', 'State', 'Seat', 'Salt', 'Salt', 'Salt', 'Salt', 'St']
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# the matched words are (inorder): ['STATE']
# the gound truth is:STATE
# top 10 matches are:  ['STATE', 'STATE', 'STARK', 'STARK', 'MIAMI', 'MIAMI', 'MIAMI', 'MIAMI', 'ADAMS', 'ADAMS']
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# the matched words are (inorder): ['State']
# the gound truth is:State
# top 10 matches are:  ['State', 'State', 'State', 'State', 'Salt', 'Salt', 'Salt', 'Salt', 'St', 'St']
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# the matched words are (inorder): ['State']
# the gound truth is:State
# top 10 matches are:  ['State', 'State', 'State', 'State', 'Salt', 'Salt', 'Salt', 'Salt', 'St', 'St']
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------

# %%
import matplotlib.pyplot as plt
# analysis of FAIRFIELD image
img_ids = set([156, 962])
for i in range(len(matched_words)):
    if i not in img_ids:
        continue
    print "************************************************************************"
    print "************************************************************************"
    print "Original image:"
    q = np.transpose(images[qualified_ids[i]],(1,2,0))
    plt.imshow(q)
    plt.show()
    print "the matched words are (inorder): "+str(matched_words[i])
    print "the gound truth is:" + str(word_strings[i])
    print "top 10 matches are: ", [word_strings[j] for j in sorted_dist[i][:10]]
    print "------------------------------------------------------------------------"
    print "------------------------------------------------------------------------"
# Out:
# ************************************************************************
# ************************************************************************
# Original image:
# the matched words are (inorder): ['FAIRFIELD']
# the gound truth is:FAIRFIELD
# top 10 matches are:  ['FAIRFIELD', 'FAIRFIELD', 'FAIRFIELD', 'WARREN', 'ALLEN', 'ALLEN', 'ALLEN', 'ALLEN', 'RIVER', 'RIVER']
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# the matched words are (inorder): ['FAIRFIELD']
# the gound truth is:FAIRFIELD
# top 10 matches are:  ['FAIRFIELD', 'FAIRFIELD', 'FAIRFIELD', 'WARREN', 'DARKE', 'DARKE', 'DARKE', 'MANSFIELD', 'MANSFIELD', 'RIVER']
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------

# %%
import matplotlib.pyplot as plt
# analysis of 13 image
img_ids = set([222, 233, 270, 331, 471, 488, 549, 685, 813, 957])
for i in range(len(matched_words)):
    if i not in img_ids:
        continue
    print "************************************************************************"
    print "************************************************************************"
    print "Original image:"
    q = np.transpose(images[qualified_ids[i]],(1,2,0))
    plt.imshow(q)
    plt.show()
    print "the matched words are (inorder): "+str(matched_words[i])
    print "the gound truth is:" + str(word_strings[i])
    print "top 10 matches are: ", [word_strings[j] for j in sorted_dist[i][:10]]
    print "------------------------------------------------------------------------"
    print "------------------------------------------------------------------------"
# Out:
# ************************************************************************
# ************************************************************************
# Original image:
# the matched words are (inorder): ['13']
# the gound truth is:13
# top 10 matches are:  ['13', '13', '13', '13', '13', '13', '13', '13', '13', '13']
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# the matched words are (inorder): ['13']
# the gound truth is:13
# top 10 matches are:  ['13', '13', '13', '13', '13', '13', '13', '13', '13', '13']
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# the matched words are (inorder): ['13']
# the gound truth is:13
# top 10 matches are:  ['13', '13', '13', '13', '13', '13', '13', '13', '13', '13']
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# the matched words are (inorder): ['13']
# the gound truth is:13
# top 10 matches are:  ['13', '13', '13', '13', '13', '13', '13', '13', '13', '13']
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# the matched words are (inorder): ['13']
# the gound truth is:13
# top 10 matches are:  ['13', '13', '13', '13', '13', '13', '13', '13', '13', '13']
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# the matched words are (inorder): ['13']
# the gound truth is:13
# top 10 matches are:  ['13', '13', '13', '13', '13', '13', '13', '13', '13', '13']
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# the matched words are (inorder): ['13']
# the gound truth is:13
# top 10 matches are:  ['13', '13', '13', '13', '13', '13', '13', '13', '13', '13']
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# the matched words are (inorder): ['13']
# the gound truth is:13
# top 10 matches are:  ['13', '13', '13', '13', '13', '13', '13', '13', '13', '13']
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# the matched words are (inorder): ['13']
# the gound truth is:13
# top 10 matches are:  ['13', '13', '13', '13', '13', '13', '13', '13', '13', '13']
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# the matched words are (inorder): ['13']
# the gound truth is:13
# top 10 matches are:  ['13', '13', '13', '13', '13', '13', '13', '13', '13', '13']
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------

# %%
import matplotlib.pyplot as plt
# analysis of great image
img_ids = set([355, 561])
for i in range(len(matched_words)):
    if i not in img_ids:
        continue
    print "************************************************************************"
    print "************************************************************************"
    print "Original image:"
    q = np.transpose(images[qualified_ids[i]],(1,2,0))
    plt.imshow(q)
    plt.show()
    print "the matched words are (inorder): "+str(matched_words[i])
    print "the gound truth is:" + str(word_strings[i])
    print "top 10 matches are: ", [word_strings[j] for j in sorted_dist[i][:10]]
    print "------------------------------------------------------------------------"
    print "------------------------------------------------------------------------"
# Out:
# ************************************************************************
# ************************************************************************
# Original image:
# the matched words are (inorder): ['GREAT']
# the gound truth is:GREAT
# top 10 matches are:  ['GREAT', 'GREAT', 'STATE', 'STATE', 'ADAMS', 'ADAMS', 'GEAUGA', 'GEAUGA', 'GEAUGA', 'GEAUGA']
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ************************************************************************
# ************************************************************************
# Original image:
# the matched words are (inorder): ['GREAT']
# the gound truth is:GREAT
# top 10 matches are:  ['GREAT', 'GREAT', 'STATE', 'STATE', 'GEAUGA', 'GEAUGA', 'GEAUGA', 'GEAUGA', 'PORTAGE', 'STARK']
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
